# %% [markdown]
# <a href="https://colab.research.google.com/github/gp17595/CE888-Labs/blob/main/Lab%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn. preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn import metrics
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
df_bank = pd.read_csv('/content/bank-additional-full.csv')

# %%
df_bank.drop('duration', axis = 1, inplace = True )

# %%
df_bank = df_bank.dropna(how='all')

# %%
df_bank[["y"]] = df_bank[["y"]].apply(LabelEncoder().fit_transform)

# %%
df_bank = pd.get_dummies(df_bank)

# %%
df_bank
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 63 columns]

# %%
df_bank['y'].hist(bins=100)

# %%
#X = df_bank['Type']
X = df_bank.iloc[:, 1:19]
print(X)
y = df_bank['y']
print(y)
# Out:
#        campaign  pdays  previous  ...  job_self-employed  job_services  job_student
# 0             1    999         0  ...                  0             0            0
# 1             1    999         0  ...                  0             1            0
# 2             1    999         0  ...                  0             1            0
# 3             1    999         0  ...                  0             0            0
# 4             1    999         0  ...                  0             1            0
# ...         ...    ...       ...  ...                ...           ...          ...
# 41183         1    999         0  ...                  0             0            0
# 41184         1    999         0  ...                  0             0            0
# 41185         2    999         0  ...                  0             0            0
# 41186         1    999         0  ...                  0             0            0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 50)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)
print np.mean(cross_val_score(clf, X_train, y_train, cv=10))
# Out:
#   File "<ipython-input-11-721b680d83ff>", line 4
#     print np.mean(cross_val_score(clf, X_train, y_train, cv=10))
#            ^
# SyntaxError: invalid syntax

# %%
dummy = DummyClassifier(strategy='uniform', random_state=1)
predict_dummy = dummy.fit(X_train, y_train)
dummy.score(X_test, y_test)
print(classification_report(y_test, predict_dummy))
